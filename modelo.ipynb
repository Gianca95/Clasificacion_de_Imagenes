# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("./test_imagen/Messi0.jpg")
img.shape
# Out:
# (390, 300, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (390, 300)

# %%
gray
# Out:
# array([[166, 166, 166, ..., 155, 155, 156],
#        [166, 166, 166, ..., 156, 157, 157],
#        [166, 166, 166, ..., 157, 158, 159],
#        ...,
#        [224, 221, 221, ..., 170, 171, 172],
#        [229, 225, 224, ..., 171, 172, 173],
#        [233, 228, 226, ..., 172, 173, 174]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 45,  78, 230, 230]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (45, 78, 230, 230)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_imagen/Messi0.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_imagen/Messi0.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_imagen/Messi8.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_imagen/Messi7.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./data/"
path_to_cr_data = "./data/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./data/Cristiano_Ronaldo',
#  './data/Messi',
#  './data/Rafael_Nadal',
#  './data/Sharapova',
#  './data/Sofia_Mulanovich']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Cristiano_Ronaldo
# Generating cropped images in folder:  ./data/cropped/Cristiano_Ronaldo
# Messi
# Generating cropped images in folder:  ./data/cropped/Messi
# Rafael_Nadal
# Generating cropped images in folder:  ./data/cropped/Rafael_Nadal
# Sharapova
# Generating cropped images in folder:  ./data/cropped/Sharapova
# Sofia_Mulanovich
# Generating cropped images in folder:  ./data/cropped/Sofia_Mulanovich

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Cristiano_Ronaldo': ['./data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo1.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo10.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo11.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo12.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo13.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo14.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo15.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo16.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo17.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo18.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo19.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo2.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo20.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo21.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo22.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo23.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo24.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo25.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo26.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo27.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo28.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo29.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo3.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo31.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo32.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo33.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo34.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo35.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo36.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo37.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo38.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo39.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo4.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo40.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo41.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo5.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo6.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo7.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo8.png',
#   './data/cropped/Cristiano_Ronaldo\\Cristiano_Ronaldo9.png'],
#  'Messi': ['./data/cropped/Messi\\Messi1.png',
#   './data/cropped/Messi\\Messi10.png',
#   './data/cropped/Messi\\Messi11.png',
#   './data/cropped/Messi\\Messi12.png',
#   './data/cropped/Messi\\Messi13.png',
#   './data/cropped/Messi\\Messi14.png',
#   './data/cropped/Messi\\Messi15.png',
#   './data/cropped/Messi\\Messi16.png',
#   './data/cropped/Messi\\Messi17.png',
#   './data/cropped/Messi\\Messi18.png',
#   './data/cropped/Messi\\Messi19.png',
#   './data/cropped/Messi\\Messi2.png',
#   './data/cropped/Messi\\Messi20.png',
#   './data/cropped/Messi\\Messi21.png',
#   './data/cropped/Messi\\Messi22.png',
#   './data/cropped/Messi\\Messi23.png',
#   './data/cropped/Messi\\Messi24.png',
#   './data/cropped/Messi\\Messi25.png',
#   './data/cropped/Messi\\Messi26.png',
#   './data/cropped/Messi\\Messi27.png',
#   './data/cropped/Messi\\Messi28.png',
#   './data/cropped/Messi\\Messi29.png',
#   './data/cropped/Messi\\Messi3.png',
#   './data/cropped/Messi\\Messi30.png',
#   './data/cropped/Messi\\Messi31.png',
#   './data/cropped/Messi\\Messi32.png',
#   './data/cropped/Messi\\Messi33.png',
#   './data/cropped/Messi\\Messi34.png',
#   './data/cropped/Messi\\Messi35.png',
#   './data/cropped/Messi\\Messi4.png',
#   './data/cropped/Messi\\Messi5.png',
#   './data/cropped/Messi\\Messi6.png',
#   './data/cropped/Messi\\Messi7.png',
#   './data/cropped/Messi\\Messi8.png',
#   './data/cropped/Messi\\Messi9.png'],
#  'Rafael_Nadal': ['./data/cropped/Rafael_Nadal\\Rafael_Nadal1.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal10.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal11.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal12.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal13.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal14.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal15.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal16.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal17.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal18.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal19.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal2.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal20.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal21.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal22.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal23.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal24.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal25.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal26.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal27.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal28.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal29.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal3.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal30.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal31.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal32.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal33.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal34.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal35.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal36.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal37.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal4.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal5.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal6.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal7.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal8.png',
#   './data/cropped/Rafael_Nadal\\Rafael_Nadal9.png'],
#  'Sharapova': ['./data/cropped/Sharapova\\Sharapova1.png',
#   './data/cropped/Sharapova\\Sharapova10.png',
#   './data/cropped/Sharapova\\Sharapova11.png',
#   './data/cropped/Sharapova\\Sharapova12.png',
#   './data/cropped/Sharapova\\Sharapova13.png',
#   './data/cropped/Sharapova\\Sharapova14.png',
#   './data/cropped/Sharapova\\Sharapova15.png',
#   './data/cropped/Sharapova\\Sharapova16.png',
#   './data/cropped/Sharapova\\Sharapova17.png',
#   './data/cropped/Sharapova\\Sharapova18.png',
#   './data/cropped/Sharapova\\Sharapova19.png',
#   './data/cropped/Sharapova\\Sharapova20.png',
#   './data/cropped/Sharapova\\Sharapova21.png',
#   './data/cropped/Sharapova\\Sharapova22.png',
#   './data/cropped/Sharapova\\Sharapova23.png',
#   './data/cropped/Sharapova\\Sharapova24.png',
#   './data/cropped/Sharapova\\Sharapova25.png',
#   './data/cropped/Sharapova\\Sharapova26.png',
#   './data/cropped/Sharapova\\Sharapova27.png',
#   './data/cropped/Sharapova\\Sharapova28.png',
#   './data/cropped/Sharapova\\Sharapova29.png',
#   './data/cropped/Sharapova\\Sharapova3.png',
#   './data/cropped/Sharapova\\Sharapova30.png',
#   './data/cropped/Sharapova\\Sharapova31.png',
#   './data/cropped/Sharapova\\Sharapova32.png',
#   './data/cropped/Sharapova\\Sharapova33.png',
#   './data/cropped/Sharapova\\Sharapova34.png',
#   './data/cropped/Sharapova\\Sharapova35.png',
#   './data/cropped/Sharapova\\Sharapova36.png',
#   './data/cropped/Sharapova\\Sharapova37.png',
#   './data/cropped/Sharapova\\Sharapova38.png',
#   './data/cropped/Sharapova\\Sharapova39.png',
#   './data/cropped/Sharapova\\Sharapova4.png',
#   './data/cropped/Sharapova\\Sharapova40.png',
#   './data/cropped/Sharapova\\Sharapova41.png',
#   './data/cropped/Sharapova\\Sharapova42.png',
#   './data/cropped/Sharapova\\Sharapova43.png',
#   './data/cropped/Sharapova\\Sharapova5.png',
#   './data/cropped/Sharapova\\Sharapova6.png',
#   './data/cropped/Sharapova\\Sharapova7.png',
#   './data/cropped/Sharapova\\Sharapova8.png',
#   './data/cropped/Sharapova\\Sharapova9.png'],
#  'Sofia_Mulanovich': ['./data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich1.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich10.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich11.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich12.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich13.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich14.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich15.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich16.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich17.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich18.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich19.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich2.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich20.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich21.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich22.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich23.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich24.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich25.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich26.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich27.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich28.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich29.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich3.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich30.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich31.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich4.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich5.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich6.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich7.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich8.png',
#   './data/cropped/Sofia_Mulanovich\\Sofia_Mulanovich9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Cristiano_Ronaldo': 0,
#  'Messi': 1,
#  'Rafael_Nadal': 2,
#  'Sharapova': 3,
#  'Sofia_Mulanovich': 4}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[113],
#        [178],
#        [163],
#        ...,
#        [243],
#        [  3],
#        [ 17]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (185, 4096)

# %%
## TRAIN MODEL

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.723404255319149

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.80      0.80      0.80        10
#            2       0.43      0.60      0.50         5
#            3       0.73      0.67      0.70        12
#            4       0.89      0.80      0.84        10
#
#     accuracy                           0.72        47
#    macro avg       0.71      0.71      0.71        47
# weighted avg       0.74      0.72      0.73        47

# %%
# USANDO GRIDSEARCH 
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.623810
# 1        random_forest    0.414286
# 2  logistic_regression    0.673016
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7659574468085106

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5531914893617021

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.851063829787234

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  1,  1,  0,  0],
#        [ 0, 10,  0,  0,  0],
#        [ 0,  0,  3,  2,  0],
#        [ 0,  1,  1, 10,  0],
#        [ 0,  0,  1,  0,  9]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Cristiano_Ronaldo': 0,
#  'Messi': 1,
#  'Rafael_Nadal': 2,
#  'Sharapova': 3,
#  'Sofia_Mulanovich': 4}

# %%
## GUARDAR EL MODELO
#!pip install joblib
#import joblib 
# Save the model as a pickle in a file 
#joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
## IMPORTA EN FORMATO .json
#import json
#with open("class_dictionary.json","w") as f:
#    f.write(json.dumps(class_dict))
